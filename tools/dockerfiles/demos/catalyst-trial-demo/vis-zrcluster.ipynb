# %%
import nglview as nv

# %%
nv.show_structure_file("zrcluster.mol2")
# Out:
# The installed widget Javascript is the wrong version.

# %%
nv.show_structure_file("renamed-zrcluster.mol2")
# Out:
# The installed widget Javascript is the wrong version.
